# %%
import pandas as pd
import numpy as np
import os
import gc
import random

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# set a seed value
torch.manual_seed(555)

import transformers
from transformers import TrainingArguments, Trainer
from transformers import EarlyStoppingCallback
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import AdamW
# Out:
# 2023-04-04 17:15:54.968045: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 17:15:55.946734: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-04 17:15:55.946846: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-04 17:15:55.946858: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# comet_ml is installed but `COMET_API_KEY` is not set.

# %%
MODEL_TYPE = 'bert-base-multilingual-cased'
L_RATE = 1e-5
MAX_LEN = 512

NUM_EPOCHS = 6
BATCH_SIZE = 2
NUM_CORES = os.cpu_count() - 2

# %%
os.environ["WANDB_DISABLED"] = "true"

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
df_train = pd.read_csv("dataset/indo_java_nli_training.csv", sep='\t')
df_train = df_train.sample(frac=1).reset_index(drop=True) #shuffle the data

# %%
df_train_new = pd.DataFrame()
df_train_new["premise"] = df_train["premise"]
df_train_new["hypothesis"] = df_train["jv_hypothesis"]
df_train_new["label"] = df_train["label"]
df_train_new.head()
# Out:
#                                              premise  \
# 0  Gempa bumi magnitudo 7,8 mengguncang sebagian ...
# 1  Dibuat dengan seukuran tubuh mereka, serta dib...
# 2  Partai Tani Indonesia adalah partai politik ya...
# 3  Empat dari penumpang Lufthansa berasal dari Je...
# 4  Menurutnya, sang adik dalam keadaan baik-baik ...
#
#                                           hypothesis  label
# 0  Kabeh kerusakan ing San Francisco ketenger gem...      1
# 1  Krono biasane dijupukaken kembang ing kono-kon...      0
# 2  Partai Petani Filipina yaiku partai politik si...      1
# 3  Jumlah penumpang Lufthansa sing mburi penerban...      2
# 4             "Adik ku masih ing pengawasan dokter."      0

# %%
df_valid = pd.read_csv("dataset/indo_java_nli_validation.csv", sep='\t')
df_valid = df_valid.sample(frac=1).reset_index(drop=True) #shuffle the data

# %%
df_valid_new = pd.DataFrame()
df_valid_new["premise"] = df_valid["premise"]
df_valid_new["hypothesis"] = df_valid["jv_hypothesis"]
df_valid_new["label"] = df_valid["label"]
df_valid_new.head()
# Out:
#                                              premise  \
# 0  Pada 15 April 2002, pesawat Air China Boeing 7...
# 1  Sementara itu, BEI mencatat frekuensi perdagan...
# 2  Dia juga tergabung dalam timnas U-17 dan U-20 ...
# 3  Syahrir mendirikan Partai Sosialis Indonesia p...
# 4  Cikande adalah desa di kecamatan Saguling, Kab...
#
#                                           hypothesis  label
# 0  Pesawat Air China yaiku pesawat sing jenengé C...      1
# 1  'Ora ana saham sing nilainipun ngisor' dalam b...      2
# 2                  Nangsa riko melu ing timnas U-17.      2
# 3        Syahrir kayadene Partai Sosialis Indonesia.      0
# 4  "Cikande ora tegese ing Kabupaten Bandung Wétan."      2

# %%
df_test = pd.read_csv("dataset/indo_java_nli_testing.csv", sep='\t')
df_test = df_test.sample(frac=1).reset_index(drop=True) #shuffle the data

# %%
df_test_new = pd.DataFrame()
df_test_new["premise"] = df_test["premise"]
df_test_new["hypothesis"] = df_test["jv_hypothesis"]
df_test_new["label"] = df_test["label"]
df_test_new.head()
# Out:
#                                              premise  \
# 0  Martina Hingis memegang rekor sebagai petenis ...
# 1  Sementara, sebelumnya pelantun hit Can 't Feel...
# 2  Menurutnya, ketersediaan pangan di DKI Jakarta...
# 3  Foto itu memperlihatkan sosok istri Raul Lemos...
# 4  Presiden Soekarno mengeluarkan Keputusan Presi...
#
#                                           hypothesis  label
# 0         Martina Hingis umur 90 taun ing taun 1997.      2
# 1  Can &#39;t Feel My Face iku judhul album kasebut.      2
# 2             Kasedhiya pangan ing DKI Jakarta aman.      0
# 3                Bojone Raul Lemos iku tukang becak.      1
# 4  Présidhèn ngangkat akèh Pahlawan Kamardikan Na...      1

# %%
tokenizer = BertTokenizer.from_pretrained(MODEL_TYPE)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]

# %%
class CompDataset(Dataset):
    def __init__(self, df):
        self.df_data = df
        
    def __getitem__(self, index):
        sentence1 = self.df_data.loc[index, 'premise']
        sentence2 = self.df_data.loc[index, 'hypothesis']
        
        encoded_dict = tokenizer.encode_plus(
            sentence1,
            sentence2,
            add_special_tokens = True,
            max_length = MAX_LEN,
            truncation='longest_first',
            padding = 'max_length',
            return_attention_mask = True,
            return_tensors = 'pt'
        )
        
        padded_token_list = encoded_dict['input_ids'][0]
        att_mask = encoded_dict['attention_mask'][0]
        
        target = torch.tensor(self.df_data.loc[index, 'label'])
        sample = {"input_ids": padded_token_list, "attention_mask": att_mask, "label": target}
        
        return sample
    
    def __len__(self):
        return len(self.df_data)

# %%
train_data_cmp = CompDataset(df_train_new)
valid_data_cmp = CompDataset(df_valid_new)
test_data_cmp = CompDataset(df_test_new)

# %%
print(f"Jumlah core: {str(NUM_CORES)}")
# Out:
# Jumlah core: 4

# %%
model = BertForSequenceClassification.from_pretrained(MODEL_TYPE, num_labels=3)

# Send the model to the device.
# model.to(device)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred, average='micro')
    precision = precision_score(y_true=labels, y_pred=pred, average='micro')
    f1 = f1_score(y_true=labels, y_pred=pred, average='weighted')

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}

# %%
training_args = TrainingArguments(
    output_dir="saved_models/Indo-Javanese-NLI/BaselineModels/bert-base-multilingual-cased",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    num_train_epochs=NUM_EPOCHS,
    seed=101,
    learning_rate=L_RATE,
    report_to="none" #"azure-ml"
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_data_cmp,
    eval_dataset=valid_data_cmp,
    compute_metrics=compute_metrics,
)

# %%
# Train pre-trained model
trainer.train()
# Out:
# /anaconda/envs/tf_gpu_research/lib/python3.7/site-packages/transformers/optimization.py:395: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
#     <div>
#
#       <progress value='30990' max='30990' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30990/30990 5:16:20, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.000900</td>
#       <td>1.056013</td>
#       <td>0.530724</td>
#       <td>0.530724</td>
#       <td>0.530724</td>
#       <td>0.516729</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.970200</td>
#       <td>1.238811</td>
#       <td>0.610833</td>
#       <td>0.610833</td>
#       <td>0.610833</td>
#       <td>0.609998</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.933800</td>
#       <td>1.323917</td>
#       <td>0.593537</td>
#       <td>0.593537</td>
#       <td>0.593537</td>
#       <td>0.594793</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.903000</td>
#       <td>1.622457</td>
#       <td>0.608557</td>
#       <td>0.608557</td>
#       <td>0.608557</td>
#       <td>0.607083</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.859200</td>
#       <td>2.001213</td>
#       <td>0.604005</td>
#       <td>0.604005</td>
#       <td>0.604005</td>
#       <td>0.604749</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.609400</td>
#       <td>2.245729</td>
#       <td>0.604005</td>
#       <td>0.604005</td>
#       <td>0.604005</td>
#       <td>0.603160</td>
#     </tr>
#   </tbody>
# </table><p>
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# TrainOutput(global_step=30990, training_loss=0.8996020031190757, metrics={'train_runtime': 18981.8016, 'train_samples_per_second': 3.265, 'train_steps_per_second': 1.633, 'total_flos': 1.630776963078144e+16, 'train_loss': 0.8996020031190757, 'epoch': 6.0})

# %%
prediction = trainer.predict(test_data_cmp)

# %%
print("Testing metrics:", prediction[2])
# Out:
# Testing metrics: {'test_loss': 2.4819486141204834, 'test_accuracy': 0.5570195365742844, 'test_precision': 0.5570195365742844, 'test_recall': 0.5570195365742844, 'test_f1': 0.5557291418423154, 'test_runtime': 210.997, 'test_samples_per_second': 10.431, 'test_steps_per_second': 5.218}

# %%
# # Preprocess raw predictions
y_pred = np.argmax(prediction[0], axis=1)

# %%
def return_label(the_label):
    str_label = ""
    if str(the_label) == "0":
        str_label = "entail"
    elif str(the_label) == "1":
        str_label = "neutral"
    else:
        str_label = "contradict"
    return str_label

# %%
for idx, row in df_test_new.iterrows():
    ground_truth = prediction[1][idx]
    if y_pred[idx] != ground_truth:
        print("==========================================================================================")
        print(f"Premis: {row['premise']}") 
        print(f"Hipotesis: {row['hypothesis']}")
        print(f"True Label: {return_label(ground_truth)}") 
        print(f"Pred Label: {return_label(y_pred[idx])}")
        print("==========================================================================================")
# Out:
# ==========================================================================================
# Premis: Sementara, sebelumnya pelantun hit Can 't Feel My Face tersebut mengakui judul albumnya Starboy terinspirasi dari hit ikonik milik David Bowie yakni Starman.
# Hipotesis: Can &#39;t Feel My Face iku judhul album kasebut.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Foto itu memperlihatkan sosok istri Raul Lemos yang tengah duduk di bangku pengemudi becak.
# Hipotesis: Bojone Raul Lemos iku tukang becak.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Dua puluh turnamen Piala Dunia telah dimenangkan oleh delapan tim nasional berbeda. Brasil telah menjuarai Piala Dunia sebanyak lima kali, dan merupakan satu-satunya tim yang secara rutin mengikuti setiap turnamen. Juara Piala Dunia lainnya adalah Italia dan Jerman dengan empat gelar juara, Argentina, Uruguay dan Prancis dengan dua gelar juara, serta Inggris dan Spanyol masing-masing dengan satu gelar juara.
# Hipotesis: Ana 9 tim nasional sing menang Piala Dunia.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Panduannya bermasalah, pertama-tama karena panduan itu dikembangkan "dalam konteks keadaan darurat".
# Hipotesis: Ora ana pandhuan sing ora nyebabake masalah.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Leonard dilaporkan sudah tidak memiliki masalah dengan pergelangan kaki kirinya, tetapi Popovich memilih tidak menurunkan pemain yang berperan sebagai small forward itu pada laga gim keenam melawan Rockets.
# Hipotesis: Leonard wis pulih kanthi lengkap.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Selama masa menjabat sebagai kepala perguruan, kesehatan Kihei amatlah buruk dan sering terbaring di tempat tidur.
# Hipotesis: Kihei wis dadi kepala sekolah.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Desa wisata Krebet tidak hanya menyimpan kearifan lokal, tapi juga memiliki keindahan alam yang tidak ada duanya.
# Hipotesis: Desa wisata Krebet nduweni alam kang jembar.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Kedokteran juga dipelajari, khususnya di selatan Italia, di mana kedokteran Islam mempengaruhi sekolah di Salerno.
# Hipotesis: Salerno dumunung ing sisih kidul Italia.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Ia bahkan sudah dipindahkan ke ruang perawatan reguler sejak hari ini, Rabu (28/6).
# Hipotesis: Dheweke dikancani kulawargane nalika dipindhah menyang ruang perawatan biasa.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Kalau ingin memandangi panorama laut dan sunset, Goa Langse adalah destinasi wisata di Jogja yang gratis dan pas untuk dituju.
# Hipotesis: Goa Langse dekat laut.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Setelah ekdisis, dalam waktu satu atau dua jam, kutikula akan mengeras dan menjadi lebih gelap. Pada masa yang pendek inilah, hewan bertumbuh, karena biasanya pada fase lain pertumbuhan dibatasi oleh kekakuan eksoskeleton.
# Hipotesis: Wutah kewan diwatesi dening kaku exoskeleton.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Cibodas Baru adalah sebuah kelurahan di wilayah Kecamatan Cibodas, Kota Tangerang, Provinsi Banten, Indonesia.
# Hipotesis: Cibodas Baru dudu desa.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Berdasarkan urutan pembagiannya, pasar ekspor Chili adalah 42% ekspor menuju Benua Amerika, 30% ke Asia, dan 24% ke Eropa.
# Hipotesis: Pasar ekspor Chile ekspor menyang Indonesia.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Namun ia berjanji untuk tidak jatuh di lubang yang sama. Rapper ini mengakhiri suratnya dengan menyatakan permintaan maafnya sekali lagi.
# Hipotesis: Rapper kasebut njaluk ngapura.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Bagi mereka yang mengikuti transisi media sosial di Capitol Hill, ini akan sedikit berbeda.
# Hipotesis: Transisi media sosial ing Capitol Hill nggawe prabédan.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Konsep ini terganggu oleh penyebaran lapisan fisik dan penerapan protokol jaringan yang tidak bersesuaian dan terlalu banyak cara berbagi sumber daya.
# Hipotesis: Konsep iki dibantu dening panyebaran lapisan fisik.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Phayao adalah sebuah kota kecil (thesaban mueang) di utara Thailand, ibu kota Provinsi Phayao.
# Hipotesis: Phayao minangka ibukutha Thailand.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Butir-butir es yang ada pada awan akan tertarik oleh gaya gravitasi bumi hingga akhirnya jatuh ke permukaan bumi. Ketika jatuh, butiran-butiran es ini akan melalui lapisan udara yang lebih hangat di dalamnya sehingga merubah butiran es tersebut menjadi butiran air.
# Hipotesis: Tetesan banyu tiba ing bumi.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Konser bertajuk Cross Genre Music ini adalah gabungan beberapa genre musik seperti jazz mainstream, pop, dan progresif.
# Hipotesis: Ana 3 genre musik ing konser Cross Genre Music.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Di sepanjang perjalanan dengan kereta api, Hyakken terus menerus minum sake ditemani Hirayama.
# Hipotesis: Hyakken mabuk sawise ngombe sake terus-terusan.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis:

# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Pada tahun 2005 produksi perkebunan rakyat yang tertinggi adalah kelapa dalam yaitu sebanyak 14.641,98 ton, menyusul kakao 10.201,54 ton, jambu mete 5.569,35 ton, kelapa hibrida 2.136,63 ton, aren/enau 1.214 ton, kopi 549,7 ton sedangkan yang terendah produksinya adalah tanaman pala yang hanya mencapai satu ton.
# Hipotesis: Produksi perkebunan jambu mete cilik ing taun 2005 ana 549,7 ton.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Winstone dinyatakan bangkrut pada tanggal 4 Oktober 1988 dan kemudian pada tanggal 19 March 1993.
# Hipotesis: Winston wis bangkrut kaping pindho.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Selain itu, jet ini merupakan satu di antara 204 pesawat yang diproduksi antara tahun 1957 dan tahun 1978 dalam proyek pribadi antara Jetstar dan Lockheed.
# Hipotesis: Jet iki minangka proyek pribadi Jetstar lan Lockhead.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Semasa perang, pemerintah membagikan pakaian seragam untuk penduduk laki-laki.
# Hipotesis: Sawisé perang, pamaréntah ora nyebar seragam.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Betapa terkejutnya ia saat melihat ternyata orang yang nyaris ia tabrak itu adalah LARA, dalam keadaan hamil besar.
# Hipotesis: LARA kaget.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Guna mengantisipasi ledakan kunjungan wisata pasca wabah COVID-19, kolaborasi usaha berbasis di Yogyakarta meluncurkan aplikasi bernama AeroConnect.
# Hipotesis: Kunjungan turis nalika wabah COVID-19 suda.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Menurut Le Figaro, rencana pemerintah ini bisa membebaskan 42 juta euro yang 15,5 jutanya akan dialokasikan untuk keamanan.
# Hipotesis: Pamrentah nyedhiyakake 15,5 yuta euro saka dhuwit sing dibebasake kanggo keamanan.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Demi Yang menguasai diriku, sungguh lilin yang ia ambil pada Perang Khaibar termasuk ghanimah yang belum dibagi.
# Hipotesis: Iku sawise Perang Khaibar.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Ada kekhawatiran bahwa mudik dapat membuka peluang bagi virus untuk menyebar ke daerah yang lebih luas.
# Hipotesis: Mudik bisa nutup kesempatan kanggo nyebarake virus.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Berpetualang bersama teman di Gunung Batu Jonggol tentu dapat menjadi kegiatan yang sangat mengasyikkan.
# Hipotesis: Akeh kegiatan sing nyenengake kajaba petualangan.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Mereka dibantu masyarakat desa yang dilalui, seperti Desa Jilatan, Tajau Pecah, Tampang, dan Sarang Halang.
# Hipotesis: Kabeh warga desa padha nulungi.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Owi/Butet yang merupakan unggulan ketiga dunia terus menambah poin dan mengubah skor menjadi 15-13. Sejurus kemudian, Tan/Lai yang tertekan melakukan kesalahan dan membuat skor berubah 17-13.
# Hipotesis: Tan/Lai ngalami tekanan lan nggawe kesalahan, mula Owi/Butet nyetak gol.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Muara Benangaq adalah salah satu kampung di kecamatan Melak, Kutai Barat, Kalimantan Timur, Indonesia.
# Hipotesis: Kabupatèn Melak, Kutai Kulon dumadi saka désa-désa.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: World Cup Willie, maskot Piala Dunia 1966, adalah maskot Piala Dunia pertama.
# Hipotesis: Maskot Piala Dunia pisanan yaiku Piala Dunia Willie.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Untuk membuat dasarnya, dibutuhkan tanah liat kurang lebih seberat 11 ton dan gibs untuk cetakannya sebanyak 6 ton.
# Hipotesis: Clay ora gibs.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Kabupaten ini dibentuk berdasarkan Undang-Undang Nomor 27 Tahun 2008 yang merupakan pemekaran dari Kabupaten Donggala.
# Hipotesis: Kabupaten iki dudu asil pembagian Kabupaten Donggala.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Hanya saja, startup rintisan dia bersama dua orang rekannya punya keunggulan yaitu fitur layaknya tes namun dikemas sebagai fun quiz.
# Hipotesis: Startup sing diwiwiti karo telung kancane duwe kaluwihan.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Melansir dari twitter Kemendikbud, Jakarta, Kamis (18/4/2019), Konferensi Asia Afrika diselenggarakan oleh Indonesia, Myanmar, India, Sri Lanka dan Pakistan.
# Hipotesis: Kajaba saka Indonesia, Myanmar, India, Sri Lanka lan Pakistan, Afrika Kidul uga nganakake Konferensi Asia Afrika.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Di Thessaly, pada tahun 352, ia mengalahkan musuhnya dan ia menguasai kuat wilayah ini.
# Hipotesis: Iku mrentah wilayah Thessaly.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Basis data dilisensikan kepada puluhan ribu distributor dan pengecer untuk sistem penjualan, situs web, dan kios.
# Hipotesis: Database kasebut dilisensi kanggo sistem penjualan, situs web lan kios.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Bagi yang terbiasa duduk sambil menyilangkan kaki, tentu saja hal itu jadi merepotkan.
# Hipotesis: Ana wong sing wis biasa lungguh karo nyabrang sikil.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Gabungan antara keindahan panorama alam dan keagungan budaya sisa peninggalan masa lalu menjadikan Dieng memiliki nilai tambah tersendiri dibanding dengan yang lain.
# ...
# Hipotesis: Nalika wong njupuk hak cipta wong, wong kasebut ora bakal diukum.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Penderita maag perlu menghindari makanan yang berlemak, goreng-gorengan, santan, mie, sayuran yang membentuk banyak gas (seperti kol, sawi, lobak), makanan terlalu pedas, kopi, minuman bersoda, dan minuman mengandung alkohol.
# Hipotesis: Sing nandhang lara lara dianjurake supaya mangan panganan sing digoreng.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Barrichello dengan tangkas mengambil alih P1 dari DC dengan selisih hanya 0,011 detik saja.
# Hipotesis: Barrichello menang.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Tembalang adalah salah satu desa di Kecamatan Tulin Onsoi, Kabupaten Nunukan, Kalimantan Timur, Indonesia.
# Hipotesis: Desa kanthi jeneng Tembalang mung ana ing pulo Kalimantan.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Middlesbrough dan Bournemouth juga gagal mempertahankan keunggulan awal menjadi kemenangan saat peluit akhir berbunyi.
# Hipotesis: Bournemouth ora tau ngrasakake kamenangan.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Ia selalu berada di pihak yang menguntungkan baginya, dan bila keadaan memburuk maka ia segera kabur.
# Hipotesis: Sisih sing migunani kanggo dheweke kabur nalika kahanan saya tambah parah.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: "Blade Runner 2049" termasuk dalam 6 genre film, yakni documentary, biography, comedy, drama, sci-fi, dan crime.
# Hipotesis: Dokumenter dudu salah sawijining genre film &quot;Blade Runner 2049&quot;.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Wonder Woman juga tercatat sebagai blockbuster pada musim panas ini dan merupakan film live action dengan pendapatan tertinggi dari seorang sutradara perempuan.
# Hipotesis: Film Wonder Woman laris dhuwur.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Setelah kandas di babak perempat final Coppa Italia oleh Udinese Calcio dan kalah bersaing dengan Juventus di pentas Serie A, Milan harus pulang dari Istanbul dengan tangan hampa setelah takluk dari Liverpool secara dramatis di laga Final Liga Champions UEFA 2005.
# Hipotesis: Liverpool kudu mulih kanthi tangan kosong ing Final Liga Champions UEFA 2005.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Album Wild West miliknya pada tahun 1981 merupakan salah satu album terlarisnya.
# Hipotesis: Album Wild West ora dirilis ing taun 1981.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Pada tahun 384, seorang biarawan India beragama Buddha, Marananta, datang ke Baekje dari Jin Timur.
# Hipotesis: Ing taun 384 Marananta rawuh ing Baekje.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Nilai tukar Rupiah terhadap dolar Amerika Serikat (AS) menguat. Dolar AS bergerak melemah dan meninggalkan level Rp13.300.
# Hipotesis: Nilai tukar dolar AS terhadap rupiah menguat.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Kasus hewan pertama yang positif COVID-19 di Amerika Serikat (AS) adalah harimau melayu berusia empat tahun di Kebun Binatang Bronx bernama Nadia, yang diyakini terinfeksi virus Corona dari seorang petugas.
# Hipotesis: Macan Malaya sing kena infeksi COVID-19 yaiku wadon.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Sesi latihan bebas kesatu GP Bahrain juga diwarnai dengan insiden yang menimpa pebalap Ferrari, Kimi Raikkonen. Pebalap Finlandia ini terpaksa menepi setelah mobil yang dikendarainya mengeluarkan asap.
# Hipotesis: Kimi Raikkonen asale saka Finlandia.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Lebaho Ulaq adalah salah satu desa di kecamatan Muara Kaman, Kabupaten Kutai Kartanegara, Kalimantan Timur, Indonesia.
# Hipotesis: Kecamatan Muara Kaman mung siji-sijine kecamatan sing nduweni desa.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Sebelumnya pada laga uji coba menghadapi Persewangi Banyuwangi, tugas sebagai juru kamera diberikan kepada Satria Tama dan Dicky. Sekarang, giliran Ravi dan Ajie yang bertugas menjadi juru kamera.
# Hipotesis: Juru kamera saiki yaiku Satria Tama lan Dicky.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Bukik Takuruang atau kerap juga disebut Tabiang Takuruang ini merupakan tempat wisata di Bukittinggi yang tengah ramai jadi perbincangan hangat.
# Hipotesis: Bukik Takuruang rame dadi rembug.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Dalam versi Mahabharata, Gatotkaca menikahi Ahilawati sang gadis naga dan mempunyai anak bernama Barbarika.
# Hipotesis: Barbarika iku putrane Gatotkaca.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Esarhadon kembali ke ibu kota Niniwe dan mengalahkan saudara-saudaranya dalam perang saudara selama 6 minggu.
# Hipotesis: Perang sipil Esarhadon lan seduluré nganti 6 jam.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Berkunjung ke Candi Dieng tidak akan menjadi pengalaman yang biasa-biasa saja.
# Hipotesis: Yen pengalamane ora biasa, ya pengalaman Dolan maring Candi Dieng.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Para ekonom Republican berhati-hati dalam mengambil data ini sebagai bukti bahwa partai mereka payah dalam kebijakan ekonomi.
# Hipotesis: Partaine pancen trampil ngurusi kebijakan ekonomi.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Warna buah ketika muda hijau gelap, dan setelah masak hijau muda hingga kuning.
# Hipotesis: Werna woh sawise mateng yaiku ijo peteng.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Croxley Rail Link akan mendanai pengalihan cabang Watford dari jalur Metropolitan ke Watford Junction, dengan mengembangkan kembali infrastruktur yang menghubungkan nya ke tempat ia akan berbagi jalur dengan London Overground.
# Hipotesis: London Overground lan Watford disambungake kanthi garis.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: