# %%
import pandas as pd
import numpy as np
import os
import gc
import random

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# set a seed value
torch.manual_seed(555)

import transformers
from transformers import TrainingArguments, Trainer
from transformers import EarlyStoppingCallback
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import AdamW
# Out:
# 2023-04-04 09:26:02.688216: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 09:26:03.645601: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-04 09:26:03.645710: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-04 09:26:03.645721: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# comet_ml is installed but `COMET_API_KEY` is not set.

# %%
MODEL_TYPE = 'bert-base-uncased'
L_RATE = 1e-5
MAX_LEN = 512

NUM_EPOCHS = 10
BATCH_SIZE = 4
NUM_CORES = os.cpu_count() - 2

# %%
os.environ["WANDB_DISABLED"] = "true"

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
df_train = pd.read_csv("dataset/indo_java_nli_training.csv", sep='\t')
df_train = df_train.sample(frac=1).reset_index(drop=True) #shuffle the data

# %%
df_train_new = pd.DataFrame()
df_train_new["premise"] = df_train["premise"]
df_train_new["hypothesis"] = df_train["jv_hypothesis"]
df_train_new["label"] = df_train["label"]
df_train_new.head()
# Out:
#                                              premise  \
# 0  Selulit sendiri merupakan kondisi munculnya ga...
# 1  Banpres adalah sebuah desa yang terletak di ke...
# 2  Itulah sebabnya masakan Indonesia memiliki cit...
# 3  Selain itu, ia juga memiliki andil dari rumah ...
# 4  "Moonlight Resonance" adalah serial drama HDTV...
#
#                                           hypothesis  label
# 0  Selulit yaiku kondhisi munculna garis halu ing...      0
# 1  Sumatera Selatan ana desa sing ana jenengé Ban...      0
# 2      Indonesia duwe rempah-rempah sing aneka rupa.      0
# 3     Sing konangan ngrangsang ing panggung gedhong.      0
# 4  "Serial drama "Moonlight Resonance" tayang nga...      1

# %%
df_valid = pd.read_csv("dataset/indo_java_nli_validation.csv", sep='\t')
df_valid = df_valid.sample(frac=1).reset_index(drop=True) #shuffle the data

# %%
df_valid_new = pd.DataFrame()
df_valid_new["premise"] = df_valid["premise"]
df_valid_new["hypothesis"] = df_valid["jv_hypothesis"]
df_valid_new["label"] = df_valid["label"]
df_valid_new.head()
# Out:
#                                              premise  \
# 0  Janji tatanan Angkatan Laut baru untuk mengama...
# 1  Kompleks Candi Dieng ini memiliki usia yang su...
# 2  Apple membeli NeXT pada tanggal 20 Desember 19...
# 3  Usai proses mentoring, imbuhnya, satu dari emp...
# 4  Namun Polri bersedia membantu bila Biro Invest...
#
#                                           hypothesis  label
# 0  Tatanan Angkatan Laut anyar ora pernah ngandhu...      2
# 1  Pembangunan kompleks Candi Dieng rampung ing a...      1
# 2                            Apple ndhuwur ing NexT.      0
# 3                  Foster ora bakal nglakoni konser.      2
# 4                         Polri saiki ngunakake FBI.      2

# %%
df_test = pd.read_csv("dataset/indo_java_nli_testing.csv", sep='\t')
df_test = df_test.sample(frac=1).reset_index(drop=True) #shuffle the data

# %%
df_test_new = pd.DataFrame()
df_test_new["premise"] = df_test["premise"]
df_test_new["hypothesis"] = df_test["jv_hypothesis"]
df_test_new["label"] = df_test["label"]
df_test_new.head()
# Out:
#                                              premise  \
# 0  Beragam penduduk asli mendiami Alaska selama r...
# 1  Tercatat 37 dokter di Italia meninggal akibat ...
# 2  "Seperti ada kerusakan di bagian belakang," ka...
# 3  Unsur busana lain yang sangat penting adalah u...
# 4  Kendati vegetasi laut hanya memiliki proporsi ...
#
#                                           hypothesis  label
# 0   Wong asli sing manggon ing Alaska ora beda-beda.      2
# 1  Luwih saka enem ewu tenaga medis uga kena infe...      0
# 2  Iku bener ana karusakan ing mburi kaya Sean ng...      1
# 3  Upuh ulen-ulen iku dudu unsur sing penting ban...      2
# 4  Kemampuan kanggo nyimpen karbon saka vegetasi ...      0

# %%
tokenizer = BertTokenizer.from_pretrained(MODEL_TYPE)

# %%
class CompDataset(Dataset):
    def __init__(self, df):
        self.df_data = df
        
    def __getitem__(self, index):
        sentence1 = self.df_data.loc[index, 'premise']
        sentence2 = self.df_data.loc[index, 'hypothesis']
        
        encoded_dict = tokenizer.encode_plus(
            sentence1,
            sentence2,
            add_special_tokens = True,
            max_length = MAX_LEN,
            truncation='longest_first',
            padding = 'max_length',
            return_attention_mask = True,
            return_tensors = 'pt'
        )
        
        padded_token_list = encoded_dict['input_ids'][0]
        att_mask = encoded_dict['attention_mask'][0]
        
        target = torch.tensor(self.df_data.loc[index, 'label'])
        sample = {"input_ids": padded_token_list, "attention_mask": att_mask, "label": target}
        
        return sample
    
    def __len__(self):
        return len(self.df_data)

# %%
train_data_cmp = CompDataset(df_train_new)
valid_data_cmp = CompDataset(df_valid_new)
test_data_cmp = CompDataset(df_test_new)

# %%
print(f"Jumlah core: {str(NUM_CORES)}")
# Out:
# Jumlah core: 4

# %%
model = BertForSequenceClassification.from_pretrained(MODEL_TYPE, num_labels=3)

# Send the model to the device.
# model.to(device)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred, average='micro')
    precision = precision_score(y_true=labels, y_pred=pred, average='micro')
    f1 = f1_score(y_true=labels, y_pred=pred, average='weighted')

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}

# %%
training_args = TrainingArguments(
    output_dir="saved_models/Indo-Javanese-NLI/BaselineModels/bert-base-epoch10",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    num_train_epochs=NUM_EPOCHS,
    seed=101,
    learning_rate=L_RATE,
    report_to="none" #"azure-ml"
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_data_cmp,
    eval_dataset=valid_data_cmp,
    compute_metrics=compute_metrics,
)

# %%
# Train pre-trained model
trainer.train()
# Out:
# /anaconda/envs/tf_gpu_research/lib/python3.7/site-packages/transformers/optimization.py:395: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
#     <div>
#
#       <progress value='25830' max='25830' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25830/25830 7:14:36, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.966500</td>
#       <td>0.966495</td>
#       <td>0.565316</td>
#       <td>0.565316</td>
#       <td>0.565316</td>
#       <td>0.569173</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.943700</td>
#       <td>0.944532</td>
#       <td>0.575330</td>
#       <td>0.575330</td>
#       <td>0.575330</td>
#       <td>0.578268</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.872600</td>
#       <td>0.957268</td>
#       <td>0.580337</td>
#       <td>0.580337</td>
#       <td>0.580337</td>
#       <td>0.584269</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.776200</td>
#       <td>1.104480</td>
#       <td>0.564861</td>
#       <td>0.564861</td>
#       <td>0.564861</td>
#       <td>0.566667</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.675200</td>
#       <td>1.226829</td>
#       <td>0.552117</td>
#       <td>0.552117</td>
#       <td>0.552117</td>
#       <td>0.551497</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.683800</td>
#       <td>1.563101</td>
#       <td>0.555303</td>
#       <td>0.555303</td>
#       <td>0.555303</td>
#       <td>0.554870</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.582100</td>
#       <td>2.122674</td>
#       <td>0.541193</td>
#       <td>0.541193</td>
#       <td>0.541193</td>
#       <td>0.543536</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.534400</td>
#       <td>2.300878</td>
#       <td>0.548475</td>
#       <td>0.548475</td>
#       <td>0.548475</td>
#       <td>0.548370</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.549900</td>
#       <td>2.405989</td>
#       <td>0.536641</td>
#       <td>0.536641</td>
#       <td>0.536641</td>
#       <td>0.534598</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.398300</td>
#       <td>2.562595</td>
#       <td>0.540282</td>
#       <td>0.540282</td>
#       <td>0.540282</td>
#       <td>0.540116</td>
#     </tr>
#   </tbody>
# </table><p>
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# TrainOutput(global_step=25830, training_loss=0.6918137252400007, metrics={'train_runtime': 26077.5836, 'train_samples_per_second': 3.961, 'train_steps_per_second': 0.991, 'total_flos': 2.71796160513024e+16, 'train_loss': 0.6918137252400007, 'epoch': 10.0})

# %%
prediction = trainer.predict(test_data_cmp)

# %%
print("Testing metrics:", prediction[2])
# Out:
# Testing metrics: {'test_loss': 2.7814669609069824, 'test_accuracy': 0.5152203543843707, 'test_precision': 0.5152203543843707, 'test_recall': 0.5152203543843707, 'test_f1': 0.517358398267481, 'test_runtime': 205.3543, 'test_samples_per_second': 10.718, 'test_steps_per_second': 2.683}

# %%
# # Preprocess raw predictions
y_pred = np.argmax(prediction[0], axis=1)

# %%
def return_label(the_label):
    str_label = ""
    if str(the_label) == "0":
        str_label = "entail"
    elif str(the_label) == "1":
        str_label = "neutral"
    else:
        str_label = "contradict"
    return str_label

# %%
for idx, row in df_test_new.iterrows():
    ground_truth = prediction[1][idx]
    if y_pred[idx] != ground_truth:
        print("==========================================================================================")
        print(f"Premis: {row['premise']}") 
        print(f"Hipotesis: {row['hypothesis']}")
        print(f"True Label: {return_label(ground_truth)}") 
        print(f"Pred Label: {return_label(y_pred[idx])}")
        print("==========================================================================================")
# Out:
# ==========================================================================================
# Premis: Beragam penduduk asli mendiami Alaska selama ribuan tahun sebelum datangnya orang Eropa ke daerah ini.
# Hipotesis: Wong asli sing manggon ing Alaska ora beda-beda.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Tercatat 37 dokter di Italia meninggal akibat terinfeksi COVID-19, sementara 6.000 lebih tenaga medis juga terinfeksi oleh virus Corona.
# Hipotesis: Luwih saka enem ewu tenaga medis uga kena infeksi virus Corona.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Kendati vegetasi laut hanya memiliki proporsi 0,05 persen dari biomassa vegetasi darat, tetapi justru memiliki kemampuan menyimpan karbon yang sebanding dengan vegetasi darat.
# Hipotesis: Kemampuan kanggo nyimpen karbon saka vegetasi segara luwih apik tinimbang vegetasi terestrial kanggo biomas padha.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Pernikahan mereka tidak sah secara hukum dan Decker bulan depan akan menikahi tunangannya. Decker menghabiskan beberapa bulan di rumah Jeffs ketika pria itu tengah dalam buruan FBI.
# Hipotesis: Decker nggarap FBI.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Demi Yang menguasai diriku, sungguh lilin yang ia ambil pada Perang Khaibar termasuk ghanimah yang belum dibagi.
# Hipotesis: Iku sawise Perang Khaibar.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis:

# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Hanya saja, ada aroma yang sedikit menyengat di pengunjung aromanya. Mungkin saja ini menggambarkan rasa sakit setelah gigi tercabut.
# Hipotesis: Ambune sing rada pedes ing mburi gondho ora bakal njlèntrèhaké rasa lara sawisé untu dicabut.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Komando Strategis Angkatan Darat atau biasa disingkat Kostrad adalah bagian dari Komando Utama (KOTAMA) tempur yang dimiliki oleh TNI Angkatan Darat. Kostrad memiliki jumlah pasukan yang dirahasiakan dan selalu siap untuk beroperasi atas perintah Panglima TNI kapan saja.
# Hipotesis: Panglima TNI iku anggota Komando Utama Tempur (KOTAMA).
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Masyarakat Badui adalah bagian dari Negara Kesatuan Republik Indonesia (NKRI), namun kepercayaan yang dianut rakyatnya belum diakui dalam kolom e-KTP.
# Hipotesis: Kapercayan masyarakat Badui wis diakoni ing kolom e-KTP.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Kembali di Belanda, Sneevliet agak tersingkirkan oleh pimpinan CPH, yang mengkritik taktiknya di Hindia Belanda.
# Hipotesis: Taktik Sneevliet pancen sampurna lan ora bisa dikritik.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Kembali di Belanda, Sneevliet agak tersingkirkan oleh pimpinan CPH, yang mengkritik taktiknya di Hindia Belanda.
# Hipotesis: Sneevliet asalé saka Walanda.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Desa wisata Krebet tidak hanya menyimpan kearifan lokal, tapi juga memiliki keindahan alam yang tidak ada duanya.
# Hipotesis: Kathah kearifan lokal ingkang tinemu ing Krebet.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Sebagai perdana menteri, ia membuat bahasa Sinhala menjadi bahasa resmi Sri Lanka dan mengusung kebijakan-kebijakan sosialis dan non-Barat.
# Hipotesis: Kawicaksanan sing digawe ora disenengi dening negara-negara Barat.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Warna parhelion akhirnya menjadi putih saat berada di lingkaran parhelis (jika dapat terlihat).
# Hipotesis: Sadurunge dadi putih, parhelion bisa uga ora ana ing bunder parhelion.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Wibowo sudah menikah dengan Retno dan dikaruniai seorang putra, yaitu Somad.
# Hipotesis: Wibowo lan Retno mung duwe anak siji, yaiku Somad.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: NASA merilis gambar spektakuler wilayah pembentuk bintang di galaksi terdekat untuk merayakan 30 tahun peluncuran teleskop Hubble ke luar angkasa.
# Hipotesis: NASA wis umur 30 taun.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: AC Milan adalah klub tersukses ke-4 di dunia sepak bola dalam hal jumlah piala internasional bersama Boca Juniors dengan 18 gelar resmi dari UEFA dan FIFA dibawah Real Madrid, FC Barcelona, dan Al-Ahly.
# Hipotesis: Ing babagan jumlah piala internasional Real Madrid ana ing sangisore AC Milan.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Nama Ian Antono mulai menarik perhatian karena pada saat itu atmosfer musik rock di Indonesia belum ada yang memulai.
# Hipotesis: Musik rock populer ing Indonesia.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Dalam lima tahun sejak Call of Duty 4 berlangsung, ia telah dipromosikan menjadi kapten di Special Air Service.
# Hipotesis: Biyen diarani Tugas 4.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Pura Ulun Danu Beratan juga sering menjadi tempat diadakannya berbagai acara, misalnya foto pre-wedding, festival seni, upacara Melasti (upacara penyucian diri untuk menyambut Hari Raya Nyepi), dan lain sebagainya.
# Hipotesis: Acara ingkang ngginakaken Pura Ulan Beratan menika namung acara religi.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Karena secara geografis terletak jauh dari pusat konflik di dataran tengah, Kerajaan Wuyue selamat dari api peperangan.
# Hipotesis: Kraton Wuyue dumunung adoh saka pusat konflik ing Semenanjung Malaka.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Pada 1948, Amir dieksekusi mati oleh pemerintah karena terlibat dalam pemberontakan komunis.
# Hipotesis: Amir dieksekusi ing taun 1947.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Sebagian besar penduduk Desa Boya Baliase berada pada usia produktif.
# Hipotesis: Kathahipun pendhudhuk Desa Boya Baliase menika sampun sepuh.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Kalau ingin memandangi panorama laut dan sunset, Goa Langse adalah destinasi wisata di Jogja yang gratis dan pas untuk dituju.
# Hipotesis: Ora perlu mbayar kanggo ngunjungi Gua Langse.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Spot wisata religi selain Pura Ulun Danu Beratan yang tidak boleh kamu lewatkan saat ke Bali adalah Pura Taman Saraswati.
# Hipotesis: Pura Ulun Danu Beratan ayu banget.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: 15 April 1936 adalah hari pertama terjadinya pemborantakan Arab di Palestina. Pemberontakan Arab di Palestina yang terjadi hingga 1939 adalah pemberontakan bangsa Arab melawan kekuasaan kolonial Britania dan imigrasi besar-besaran orang Yahudi di Palestina.
# Hipotesis: Wong Arab ora tau nglawan penjajah Inggris.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Pegunungan Alpen menyediakan air, irigasi, dan listrik tenaga air bagi dataran rendah Eropa.
# Hipotesis: Sumber utama banyu lan irigasi kanggo dataran rendah Eropa yaiku saka Alpen.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ...
# Hipotesis: Busana &#39;eksentrik&#39; ngundang hiburan.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Belum lama pekan ini, Marco Tronchetti Provera, bos Pirelli yang menjadi sponsor terbesar Inter, mengungkapkan impiannya menyaksikan Messi mengenakan seragam Inter suatu hari nanti.
# Hipotesis: Pimpinan Pirelli Marco Tronchetti Provera ngarep-arep Messi bakal nganggo klambi Inter sedina.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Serupa pula dengan di Indonesia, untuk gelaran di China pun masih menunggu peningkatan fasilitas dari sirkuit yang akan dipakai di Shanghai atau Zhejiang.
# Hipotesis: China bakal nindakake judhul.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Kawasan Asia Tenggara terdiri dari bentang darat dan air. Bentang darat adalah bagian penting sebagai tempat tinggal dan aktivitas penduduk.
# Hipotesis: Lanskap iku panggonan wong urip.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Untuk melengkapi formasi, Bons dari Tengkorak dan Andyan dari Siksakubur diajak untuk bergabung.
# Hipotesis: Bons lan Andyan ora gelem melu.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Bentuk sederhana dari kontrol aliran dikenal sebagai stop and wait.
# Hipotesis: Stop minangka wangun kontrol aliran sing prasaja.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Akan tetapi, Nurdin bersikeras untuk tidak mundur dari jabatannya sebagai ketua PSSI dan tetap menjalankan kepemimpinan PSSI dari balik jeruji penjara.
# Hipotesis: PSSI ora gelem Nurdin nerusake kepemimpinane dadi ketua PSSI.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Pun dengan Petty Jenkins yang mematahkan anggapan film komersil akan sukses dipegang sutradara laki-laki.
# Hipotesis: Petty Jenkins sukses kaya sutradara lanang liyane sing sukses.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Saat itu, Atkinson beradu akting dengan Dominic West, Gillian Anderson dan Rosamund Pike.
# Hipotesis: Atkinson wis tau tumindak karo Dominic West.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Saat ini, maksimal denda yang dapat dikenakan oleh RECO terhadap agen adalah $25.000.
# Hipotesis: Agen bisa mbayar denda ing pengadilan.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Akri mulai dikenal sejak bergabung bersama Eko dan Parto dalam kelompok lawak Patrio.
# Hipotesis: Akri ora tau melu grup komedi.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Berkunjung ke Candi Dieng tidak akan menjadi pengalaman yang biasa-biasa saja.
# Hipotesis: Ngunjungi Candi Dieng bakal dadi pengalaman sing apik.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Bagi mereka yang mengikuti transisi media sosial di Capitol Hill, ini akan sedikit berbeda.
# Hipotesis: Transisi media sosial ing Capitol Hill nggawe prabédan.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Berdasarkan Surat Keputusan Menteri Dalam Negeri Nomor: 140/502 tanggal 22 September 1980 tentang penetapan desa menjadi kelurahan, maka sejak saat itulah desa Alalak Selatan resmi menjadi Kelurahan Alalak Selatan wilayah Kecamatan Banjarmasin Utara.
# Hipotesis: Wilayah Desa Alalak Selatan lan Desa Alalak Selatan padha.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Dia dikenal karena telah membawa perhatian tentang Awam dalam Konsili Vatikan II, dan sebagai pendiri Legio Maria.
# Hipotesis: Legiun Maria didegaké déning luwih saka siji wong.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Sungai adalah aliran air yang besar dan memanjang yang mengalir secara terus-menerus dari hulu (sumber) menuju hilir (muara). Pengertian lain dari sungai yaitu aliran air di daratan yang menuju danau, laut, dan atau sungai lainnya.
# Hipotesis: Kali iki mili saka hulu menyang hilir.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Semasa perang, pemerintah membagikan pakaian seragam untuk penduduk laki-laki.
# Hipotesis: Sawisé perang, pamaréntah ora nyebar seragam.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Faktor di balik kemenangan Traian Băsescu adalah janjinya melakukan reformasi hukum, penjagaan perbatasan, pemberantasan korupsi dan kemiskinan, serta pengetatan subsidi pada badan usaha milik negara.
# Hipotesis: Traian Băsescu menang amarga sawetara faktor.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Pura Besakih merupakan tempat sembayang para umat Hindu di Bali.
# Hipotesis: Candhi Besakih minangka papan pangibadah umat Hindhu ing Tanah Jawa.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Ia selalu berada di pihak yang menguntungkan baginya, dan bila keadaan memburuk maka ia segera kabur.
# Hipotesis: Sisih sing migunani kanggo dheweke kabur nalika kahanan saya tambah parah.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Pantai Nyang Nyang memang belum begitu terkenal jika dibandingkan pantai lainnya di Bali yang memang sudah cukup populer.
# Hipotesis: Pantai Nyang Nyang misuwur banget.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Sebelumnya pada laga uji coba menghadapi Persewangi Banyuwangi, tugas sebagai juru kamera diberikan kepada Satria Tama dan Dicky. Sekarang, giliran Ravi dan Ajie yang bertugas menjadi juru kamera.
# Hipotesis: Juru kamera saiki yaiku Satria Tama lan Dicky.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Ia berusaha menggabungkan Nash-Kelvinator Corporation dan Hudson Motor Car Company untuk berkompetisi dengan "Big Three" (General Motors, Ford dan Chrysler).
# Hipotesis: Ford dudu salah sawijining &quot;Tiga Besar&quot;
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Iklim di wilayah Asia Tenggara merupakan iklim tropis.
# Hipotesis: Iklim ing tlatah Asia Kidul-Wétan iku subtropis.
# True Label: contradict
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Bartholoma ialah sebuah kota di distrik Ostalbkreis, negara bagian Baden-Wurttemberg, negara Jerman.
# Hipotesis: Bartholoma ana ing Eropah.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Salah satu kota yang biasanya tak luput jadi singgahan para wisatawan di Sumatera Barat adalah Bukittinggi.
# Hipotesis: Bukittinggi is in West Sumatra.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Magma ini cenderung sangat kental karena kandungan silika nya tinggi, sehingga tidak mencapai permukaan melainkan mendingin di kedalaman.
# Hipotesis: Magma iki ngandhut kandungan wesi.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Dari 1892 hingga 1895, ia dipersiapkan untuk menempuh ujian masuk universitas yang dilewatinya pada 1895.
# Hipotesis: Ujian mlebu universitas dianakaké ing taun 1895.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Beredar pesan di Whatsapp yang menjelaskan bahaya dari pemakaian ventilator bagi pasien COVID-19.
# Hipotesis: Whatsapp asring digunakake kanggo nyebar bebaya.
# True Label: neutral
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Pameran bertajuk "Titanic—The Promise of Modernity" ini digagas oleh seniman Yadegar Asisi, sedangkan musisi Eric Babak kebagian menggarap musik guna menambah dramatis suasana pameran.
# Hipotesis: &quot;Titanic-The Promise of Modernity&quot; minangka pameran sing diwiwiti dening Yadegar Assisi.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Berdasarkan data terbaru yang dirilis Gugus Tugas Percepatan Penanganan Covid-19 pada Selasa sore, 28 April 2020, total jumlah kasus positif corona di Indonesia kini mencapai 9.511 pasien.
# Hipotesis: Gunggunge kasus positif korona ing Indonesia meh udakara 10 ewu pasien.
# True Label: entail
# Pred Label: neutral
# ==========================================================================================
# ==========================================================================================
# Premis: Sistem Finlandia ini memungkinkan ilmuwan melihat abu dan awan yang dihembuskan gunung api untuk mendeteksi permukaan gunung.
# Hipotesis: Sistem sing ngidini para ilmuwan kanggo ndeleng awu lan mega exhaled dening gunung geni kanggo ndeteksi lumahing gunung asalé saka Finlandia.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Pada tahun 2005 produksi perkebunan rakyat yang tertinggi adalah kelapa dalam yaitu sebanyak 14.641,98 ton, menyusul kakao 10.201,54 ton, jambu mete 5.569,35 ton, kelapa hibrida 2.136,63 ton, aren/enau 1.214 ton, kopi 549,7 ton sedangkan yang terendah produksinya adalah tanaman pala yang hanya mencapai satu ton.
# Hipotesis: Wong seneng klapa.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Pavlovsky adalah presiden dari Yayasan Politik yang Efektif (FEP).
# Hipotesis: Pavlovsky dudu presiden.
# True Label: contradict
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: Bukan semata memiliki nuansa religius, Pura Ulun Danu Beratan yang letaknya di kawasan Danau Bratan juga menawarkan panorama yang cantiknya bukan main.
# Hipotesis: Pura Ulun Danu Beratan dumunung ing tlatah Tlaga Bratan.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Dia terus muncul di lumbung ku dan saya berkelakar kepada orang itu bahwa dia jelas-jelas tidak ingin dijual.
# Hipotesis: Aku guyon yen dheweke ora pengin didol.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
# ==========================================================================================
# Premis: Film kedua masih mengisahkan Kevin seorang diri saat libur Natal dan Tahun Baru.
# Hipotesis: Kevin ngrayakake Natal.
# True Label: neutral
# Pred Label: entail
# ==========================================================================================
# ==========================================================================================
# Premis: "Penyakit fatal dapat terjadi jika sakit maag tidak ditangani dengan baik karena gejala sakit maag dapat juga merupakan gejala dari suatu penyakit yang serius," ujar dr Helmin kepada detikHealth, Selasa (28/4/2020).
# Hipotesis: Heartburn bisa mungkasi karo penyakit serius.
# True Label: entail
# Pred Label: contradict
# ==========================================================================================
